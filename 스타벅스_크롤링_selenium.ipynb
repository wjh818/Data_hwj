# %%
from selenium import webdriver
import pandas as pd
import time

chromedriver_dir = r'C:\Users\BIT_R45\chromedriver.exe'
driver = webdriver.Chrome(chromedriver_dir)
time.sleep(3)

# %%
driver.get('https://www.starbucks.co.kr/store/store_map.do')
# driver.get(url)은 파이썬이 브라우저를 시켜서 url로 get 요청을 한 것

# %%
loca = driver.find_element_by_class_name('loca_search')
loca.click()
time.sleep(3)

# %%
sido = driver.find_element_by_class_name('sido_arae_box')
li = sido.find_elements_by_tag_name('li')
li[0].click()
time.sleep(3)

# %%
gugun = driver.find_element_by_class_name('gugun_arae_box')
guli = gugun.find_element_by_tag_name('li')
guli.click()
time.sleep(3)

# %%
source = driver.page_source

# %%
import bs4
source = driver.page_source
bs = bs4.BeautifulSoup(source, 'lxml')
entire = bs.find('ul', class_='quickSearchResultBoxSidoGugun')
li_list = entire.find_all('li')

# %%
lat_long = entire.find_all('li', class_='quickResultLstCon')

# %%
lat_long
# Out:
# [<li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong>역삼아레나빌딩  <img alt="" class="setStoreFavBtn mCS_img_loaded" data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N" src="//image.istarbucks.co.kr/common/img/store/icon_fav_off.png"/></strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>,
# ...

# %%
lat_list = []

# %%
for i in range(len(lat_long)):
    lat_list.append(lat_long[i]['data-lat'])

# %%
lat_list
# Out:
# ['37.501087',
#  '37.510178',
#  '37.514132',
#  '37.499517',
#  '37.494668',
#  '37.515000',
#  '37.5227934',
#  '37.510150',
#  '37.507750',
#  '37.5273669',
#  '37.488008',
#  '37.485192',
#  '37.505321',
#  '37.511293',
#  '37.502117',
#  '37.50999',
#  '37.518181',
#  '37.492805',
#  '37.497711',
#  '37.498973',
#  '37.522156',
#  '37.526283',
#  '37.521852',
#  '37.525216',
#  '37.492396',
#  '37.52236449999999',
#  '37.503331',
#  '37.5075307',
#  '37.5191632',
#  '37.5162021',
#  '37.492167',
#  '37.514887',
#  '37.5236351',
#  '37.496801',
#  '37.4941059',
#  '37.513715',
#  '37.5231593',
#  '37.501623',
#  '37.499721',
#  '37.50314',
#  '37.5243631',
#  '37.5097863',
#  '37.507794',
#  '37.51464884',
#  '37.49966175',
#  '37.50329211',
#  '37.490298',
#  '37.50703529',
#  '37.50377562',
#  '37.52674095',
#  '37.52680046',
#  '37.49592355',
#  '37.50236693',
#  '37.5165849',
#  '37.493554',
#  '37.47781106',
#  '37.49971982',
#  '37.49803646',
#  '37.51075489999999',
# ...

# %%
long_list = []

# %%
for i in range(len(lat_long)):
    long_list.append(lat_long[i]['data-long'])

# %%
long_list
# Out:
# ['127.043069',
#  '127.022223',
#  '127.020563',
#  '127.031495',
#  '127.062583',
#  '127.063196',
#  '127.0286009',
#  '127.060275',
#  '127.060651',
#  '127.033061',
#  '127.102650',
#  '127.036685',
#  '127.050409',
#  '127.048409',
#  '127.026672',
#  '127.061455',
#  '127.045995',
#  '127.041309',
#  '127.028439',
#  '127.060172',
#  '127.056449',
#  '127.029560',
#  '127.022510',
#  '127.041827',
#  '127.030910',
#  '127.03795430000002',
#  '127.058817',
#  '127.05742710000004',
#  '127.0286446',
#  '127.0207428',
#  '127.057398',
#  '127.035653',
#  '127.04686509999999',
#  '127.055055',
#  '127.03299730000003',
#  '127.059245',
#  '127.02162499999997',
#  '127.039375',
#  '127.033582',
#  '127.025546',
#  '127.05155990000003',
#  '127.05791339999996',
#  '127.06517',
#  '127.0307302',
#  '127.0622171',
#  '127.0436409',
#  '127.054895',
#  '127.0555503',
#  '127.051196',
#  '127.0281105',
#  '127.0347174',
#  '127.0388645',
#  '127.0407',
#  '127.04124330000002',
# ...

# %%
for info in li_list:
    print(info.find('p').text)
# Out:
# 서울특별시 강남구 언주로 425 (역삼동)1522-3232
# 서울특별시 강남구 강남대로 538 (논현동)1522-3232
# 서울특별시 강남구 강남대로 584 (논현동)1522-3232
# 서울특별시 강남구 테헤란로 125 (역삼동)1522-3232
# 서울특별시 강남구 남부순환로 2947 (대치동)1522-3232
# 서울특별시 강남구 봉은사로 619 (삼성동)1522-3232
# 서울특별시 강남구 논현로 834 (신사동)1522-3232
# 서울특별시 강남구 영동대로 513 (삼성동)1522-3232
# 서울특별시 강남구 테헤란로 518 (대치동)1522-3232
# 서울특별시 강남구 언주로 861 (신사동)1522-3232
# 서울특별시 강남구 광평로 281 (수서동)1522-3232
# 서울특별시 강남구 남부순환로 2621 (도곡동)1522-3232
# 서울특별시 강남구 테헤란로 409 (삼성동)1522-3232
# 서울특별시 강남구 봉은사로 446 (삼성동)1522-3232
# 서울특별시 강남구 봉은사로2길 39 (역삼동)1522-3232
# 서울특별시 강남구 영동대로 513 (삼성동) 코엑스 A106호1522-3232
# 서울특별시 강남구 학동로 419 (청담동)1522-3232
# 서울특별시 강남구 도곡로 205 (역삼동)1522-3232
# 서울특별시 강남구 강남대로 390 (역삼동)1522-3232
# 서울특별시 강남구 도곡로 457 (대치동)1522-3232
# 서울특별시 강남구 영동대로 720 (청담동)1522-3232
# 서울특별시 강남구 압구정로30길 17 (신사동)1522-3232
# 서울특별시 강남구 가로수길 59 1522-3232
# 서울특별시 강남구 도산대로57길 24 (청담동)1522-3232
# 서울특별시 강남구 강남대로 328 (역삼동)1522-3232
# 서울특별시 강남구 도산대로 328 (논현동)1522-3232
# 서울특별시 강남구 삼성로 402 (대치동)1522-3232
# ...

# %%
l1 = []

# %%
for info in li_list:
    l1.append(info.find('p').text)

# ..                                          ...
# 523                   서울특별시 중랑구 신내로 721522-3232
# 524                  서울특별시 중랑구 면목로 3101522-3232
# 525    서울특별시 중랑구 망우로 307, ,3,4번지 (상봉동)1522-3232
# 526  서울특별시 중랑구 동일로 932, 묵동이마트 B1층 (묵동)1522-3232
# 527                 서울특별시 중랑구 동일로 952 1522-3232
#
# [528 rows x 1 columns]

# %%
df
# Out:
#                                              주소
# 0              서울특별시 강남구 언주로 425 (역삼동)1522-3232
# 1             서울특별시 강남구 강남대로 538 (논현동)1522-3232
# 2             서울특별시 강남구 강남대로 584 (논현동)1522-3232
# 3             서울특별시 강남구 테헤란로 125 (역삼동)1522-3232
# 4           서울특별시 강남구 남부순환로 2947 (대치동)1522-3232
# ..                                          ...
# 523                   서울특별시 중랑구 신내로 721522-3232
# 524                  서울특별시 중랑구 면목로 3101522-3232
# 525    서울특별시 중랑구 망우로 307, ,3,4번지 (상봉동)1522-3232
# 526  서울특별시 중랑구 동일로 932, 묵동이마트 B1층 (묵동)1522-3232
# 527                 서울특별시 중랑구 동일로 952 1522-3232
#
# [528 rows x 1 columns]

# %%
df['경도']=long_list

# %%
df
# Out:
#                                              주소           경도
# 0              서울특별시 강남구 언주로 425 (역삼동)1522-3232   127.043069
# 1             서울특별시 강남구 강남대로 538 (논현동)1522-3232   127.022223
# 2             서울특별시 강남구 강남대로 584 (논현동)1522-3232   127.020563
# 3             서울특별시 강남구 테헤란로 125 (역삼동)1522-3232   127.031495
# 4           서울특별시 강남구 남부순환로 2947 (대치동)1522-3232   127.062583
# ..                                          ...          ...
# 523                   서울특별시 중랑구 신내로 721522-3232  127.0957558
# 524                  서울특별시 중랑구 면목로 3101522-3232   127.087966
# 525    서울특별시 중랑구 망우로 307, ,3,4번지 (상봉동)1522-3232    127.08647
# 526  서울특별시 중랑구 동일로 932, 묵동이마트 B1층 (묵동)1522-3232   127.077484
# 527                 서울특별시 중랑구 동일로 952 1522-3232   127.076633
#
# [528 rows x 2 columns]

# %%
df['주소']
# Out:
# 0                서울특별시 강남구 언주로 425 (역삼동)1522-3232
# 1               서울특별시 강남구 강남대로 538 (논현동)1522-3232
# 2               서울특별시 강남구 강남대로 584 (논현동)1522-3232
# 3               서울특별시 강남구 테헤란로 125 (역삼동)1522-3232
# 4             서울특별시 강남구 남부순환로 2947 (대치동)1522-3232
#                           ...
# 523                     서울특별시 중랑구 신내로 721522-3232
# 524                    서울특별시 중랑구 면목로 3101522-3232
# 525      서울특별시 중랑구 망우로 307, ,3,4번지 (상봉동)1522-3232
# 526    서울특별시 중랑구 동일로 932, 묵동이마트 B1층 (묵동)1522-3232
# 527                   서울특별시 중랑구 동일로 952 1522-3232
# Name: 주소, Length: 528, dtype: object

# %%
a = df['주소'][0].split(" ")

# %%
a[1]
# Out:
# '강남구'

# %%
len(df['주소'])
# Out:
# 528

# %%
gu_list = []

# %%
for i in range(len(df['주소'])):
    a = df['주소'][i].split(" ")
    gu_list.append(a[1])

# %%
gu_list
# Out:
# ['강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
# ...

# %%
df['구'] = gu_list

# %%
df
# Out:
#                                              주소           경도    구
# 0              서울특별시 강남구 언주로 425 (역삼동)1522-3232   127.043069  강남구
# 1             서울특별시 강남구 강남대로 538 (논현동)1522-3232   127.022223  강남구
# 2             서울특별시 강남구 강남대로 584 (논현동)1522-3232   127.020563  강남구
# 3             서울특별시 강남구 테헤란로 125 (역삼동)1522-3232   127.031495  강남구
# 4           서울특별시 강남구 남부순환로 2947 (대치동)1522-3232   127.062583  강남구
# ..                                          ...          ...  ...
# 523                   서울특별시 중랑구 신내로 721522-3232  127.0957558  중랑구
# 524                  서울특별시 중랑구 면목로 3101522-3232   127.087966  중랑구
# 525    서울특별시 중랑구 망우로 307, ,3,4번지 (상봉동)1522-3232    127.08647  중랑구
# 526  서울특별시 중랑구 동일로 932, 묵동이마트 B1층 (묵동)1522-3232   127.077484  중랑구
# 527                 서울특별시 중랑구 동일로 952 1522-3232   127.076633  중랑구
#
# [528 rows x 3 columns]

# %%
a = df['구'].value_counts()

# %%
a.index.tolist()
# Out:
# ['강남구',
#  '중구',
#  '서초구',
#  '종로구',
#  '영등포구',
#  '마포구',
#  '송파구',
#  '용산구',
#  '서대문구',
#  '광진구',
#  '강서구',
#  '강동구',
#  '양천구',
#  '성북구',
#  '성동구',
#  '노원구',
#  '관악구',
#  '구로구',
#  '금천구',
#  '동작구',
#  '동대문구',
#  '은평구',
#  '중랑구',
#  '강북구',
#  '도봉구']

# %%
gu_counts = df['구'].value_counts().tolist()

# %%
df_c = pd.DataFrame()

# %%
df_c['gu'] = a.index.tolist()
df_c['gu_c'] = gu_counts

# %%
df_c
# Out:
#       gu  gu_c
# 0    강남구    81
# 1     중구    54
# 2    서초구    47
# 3    종로구    37
# 4   영등포구    34
# 5    마포구    32
# 6    송파구    32
# 7    용산구    19
# 8   서대문구    19
# 9    광진구    16
# 10   강서구    16
# 11   강동구    15
# 12   양천구    15
# 13   성북구    13
# 14   성동구    12
# 15   노원구    12
# 16   관악구    11
# 17   구로구    11
# 18   금천구    11
# 19   동작구    11
# 20  동대문구     8
# 21   은평구     8
# 22   중랑구     7
# 23   강북구     5
# 24   도봉구     2

# %%
center = [37.541, 126.986]
m = folium.Map(location=center, zoom_start=10)

# %%
geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# %%
from folium import Choropleth

folium.Choropleth(
    geo_data = geo_json,
    name='choropleth',
    data = df_c,
    columns=['gu', 'gu_c'],
    key_on='feature.properties.name',
    fill_color='PuBu',
    fill_opacity=0.85, 
    line_opacity=0.2,
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
